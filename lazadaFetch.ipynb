# %%
import pandas as pd
import numpy as np

# %%
for i in range(1001):
    path = 'out' + str(i) + ".csv"
    print(path)
    try:
        df = pd.read_csv(path)
    except: 
        pass
    df.to_csv('lazadaReviewTemp.csv', mode='a', header=False)
print('Temp Done')

createNewFile = pd.read_csv('lazadaReviewTemp.csv', names=["itemId", "sellerId", "buyerId", "itemTitle", "reviewType", "rating", "reviewContent", "isAnonymous", "boughtDate", "reviewTime"])

createNewFile.to_csv('lazadaReviewData0_1000.csv')
print('CreateFile Done')
# Out:
# out0.csv
# out1.csv
# out2.csv
# out3.csv
# out4.csv
# out5.csv
# out6.csv
# out7.csv
# out8.csv
# out9.csv
# out10.csv
# out11.csv
# out12.csv
# out13.csv
# out14.csv
# out15.csv
# out16.csv
# out17.csv
# out18.csv
# out19.csv
# out20.csv
# out21.csv
# out22.csv
# out23.csv
# out24.csv
# out25.csv
# out26.csv
# out27.csv
# out28.csv
# out29.csv
# out30.csv
# out31.csv
# out32.csv
# out33.csv
# out34.csv
# out35.csv
# out36.csv
# out37.csv
# out38.csv
# out39.csv
# out40.csv
# out41.csv
# out42.csv
# out43.csv
# out44.csv
# out45.csv
# out46.csv
# out47.csv
# out48.csv
# out49.csv
# out50.csv
# out51.csv
# out52.csv
# out53.csv
# out54.csv
# out55.csv
# out56.csv
# out57.csv
# out58.csv
# out59.csv
# out60.csv
# out61.csv
# out62.csv
# out63.csv
# out64.csv
# out65.csv
# out66.csv
# out67.csv
# out68.csv
# out69.csv
# out70.csv
# out71.csv
# out72.csv
# out73.csv
# out74.csv
# out75.csv
# out76.csv
# out77.csv
# out78.csv
# out79.csv
# out80.csv
# out81.csv
# out82.csv
# out83.csv
# ...
